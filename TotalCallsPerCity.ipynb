# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np

# Load the dataset
df = pd.read_csv('Call_Center.csv')

# Group the data by 'City' and calculate the total number of calls
city_calls = df.groupby('City').size().reset_index(name='Total Calls')

# Use the 'Total Calls' column as a feature for K-Means clustering
X = city_calls[['Total Calls']]

# Choose the number of clusters (k)
k = 3  # You can change this to the desired number of clusters

# Create and fit the K-Means model
kmeans = KMeans(n_clusters=k, random_state=42)
city_calls['Cluster'] = kmeans.fit_predict(X)

# Print the clustering results
print(city_calls)
# Out:
#               City  Total Calls  Cluster
# 0          Abilene           33        0
# 1            Aiken           17        0
# 2            Akron          105        0
# 3           Albany          187        1
# 4      Albuquerque          162        1
# ..             ...          ...      ...
# 456        Yonkers            7        0
# 457           York           16        0
# 458  Young America           65        0
# 459     Youngstown           56        0
# 460    Zephyrhills           16        0
#
# [461 rows x 3 columns]
# /Users/minalchhatre/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Load the dataset
df = pd.read_csv('Call_Center.csv')

# Group the data by 'City' and calculate the total number of calls
city_calls = df.groupby('City').size().reset_index(name='Total Calls')

# Use the 'Total Calls' column as a feature for K-Means clustering
X = city_calls[['Total Calls']]

# Choose the number of clusters (k)
k = 3  # You can change this to the desired number of clusters

# Create and fit the K-Means model
kmeans = KMeans(n_clusters=k, random_state=42)
city_calls['Cluster'] = kmeans.fit_predict(X)

# Plot the bar chart
plt.figure(figsize=(10, 6))
for cluster in range(k):
    cluster_data = city_calls[city_calls['Cluster'] == cluster]
    plt.bar(cluster_data['City'], cluster_data['Total Calls'], label=f'Cluster {cluster}')

plt.xlabel('City')
plt.ylabel('Total Calls')
plt.title('Total Calls per City by Clusters')
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# /Users/minalchhatre/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
